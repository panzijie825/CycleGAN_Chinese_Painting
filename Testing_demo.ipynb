# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('drive/My Drive/CV_project')
# !ls
# Out:
# datasets     download_dataset.sh  output       testing_demo.ipynb  utils.py
# datasets.py  LICENSE		  __pycache__  test.py
# demo.ipynb   models.py		  README.md    train.py

# %%
! python test.py --dataroot datasets/chinese/ --cuda
# Out:
# Namespace(batchSize=1, cuda=True, dataroot='datasets/chinese/', generator_A2B='output/netG_A2B100.pth', generator_B2A='output/netG_B2A100.pth', input_nc=3, n_cpu=8, output_nc=3, size=256)
# Generated images 0020 of 0020
